# %%
import pandas as pd
from chython import smarts

# %%
df = pd.read_csv('../reference/n1_classified_alchemical_rules_neg.tsv', sep='\t')
df[:10]
# Out:
#                                      Alchemical_rule  output_reactants_num  \
# 0  [C;D3:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[C;D3:1]...                     2
# 1  [C;D2:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[N;D1-:3...                     2
# 2  [C;D2:1]-[C;D3:2](=[O;D1:3])-[N;D2:4]-[C;D2:5]...                     2
# 3  [C;D2:1]-[C;D2:2]=[O;D1:3]>>[C;D2:1]-[C;D3:2](...                     1
# 4  [C;D2:1]-[C;D3:2](=[O;D1:3])-[N;D3:4](-[C;D2:5...                     2
# 5  [C;D3:1]-[C;D2:2]-[O;D1:3]>>[C;D3:1]-[C;D3:2](...                     1
# 6  [C;D3:1]-[C;D2:2]=[O;D1:3]>>[C;D3:1]-[C;D3:2](...                     1
# 7  [C;D3:1]-[C;D2:2]=[O;D1:3]>>[C;D3:1]-[C;D3:2](...                     1
# 8  [C;D2:1]-[C;D2:2]-[N;D3:3](-[C;D3:4])-[C;D3:5]...                     2
# 9  [C;D3:1]-[C;D2:2]-[N;D2:3]-[C;D2:4]>>[C;D3:1]-...                     2
#
#    popularity  route_ids_size  \
# 0          27              27
# 1          21              21
# 2          15              15
# 3          10              10
# 4           9               9
# 5           9               9
# 6           8               8
# 7           8               8
# 8           7               7
# 9           7               7
#
#                                            Reference  \
# 0  4,44,151,314,322,489,492,744,1051,1077,1148,16...
# 1  231,333,427,1090,1204,1357,1472,1792,2247,2281...
# 2  162,980,1027,1390,1583,1942,1973,3507,4071,552...
# 3    174,378,1274,1380,2072,3782,4912,5256,6247,8819
# 4          75,148,1014,1183,1428,2174,3161,4977,6354
# 5         418,924,1167,1713,1991,3862,4827,5264,6362
# 6              681,981,2504,5227,5647,5690,6362,7100
# 7                437,681,706,836,5227,5557,6586,6946
# 8                     96,436,479,1336,1389,5532,9892
# 9                    21,882,3776,7334,7385,8296,8830
#
#                                     Target_molecules  composite_rules_size  \
# 0  C=C1[C@@H](OC(C)=O)C[C@H]2[C@H](CN=[N+]=[N-])[...                     3
# 1  C#CCCCCN=[N+]=[N-],CC(C)(C)OC(=O)COCCOCCOCCOCC...                     5
# 2  CC1CCCC(CC(=O)NCC(N)=O)C1,CCC(=NOCc1ccc(C(F)(F...                     7
# 3  CC(=O)N[C@@H](CC=O)c1cccc(F)c1,CC(=O)N[C@@H]1C...                     2
# 4  CC(C)(C)OC(=O)Nc1cc(Cl)ccc1/C=C/C(=O)N1CCN(Cc2...                     2
# 5  CC(C)[C@@H](CO)NC(=O)OC(C)(C)C,CC(c1c[nH]cn1)C...                     4
# 6  CC#CCC(C=O)NC(=O)OC(C)(C)C,CC(C)(C)OC(=O)N[C@H...                     3
# 7  CC#CCC(C=O)NC(=O)OC(C)(C)C,CC(C=O)Oc1ccc(Oc2cc...                     4
# 8  C=CCCCCN1C(=O)c2ccccc2C1=O,CCCCCc1ccc(CCCN2C(=...                     5
# 9  CC(C)(C)OC(=O)N1[C@H](CNCc2ccccc2)C[C@@H]2CCC[...                     3
#
#   Composite_rule_sizes                                    Composite_rules  \
# 0                    2  [C;D3:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[C;D3:1]...
# 1                    2  [C;D2:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[C;D2:1]...
# 2                  2,3  [C;D2:1]-[C;D3:2](=[O;D1:3])-[N;D2:4]-[C;D2:5]...
# 3                    2  [C;D2:1](-[C;D2:2])=[O;D1:3]>>[C;D2:1](-[C;D2:...
# 4                    2  [C;D2:1]-[C;D3:2](-[N;D3:3](-[C;D2:4])-[C;D2:5...
# 5                    2  [C;D2:1](-[C;D3:2])-[O;D1:3]>>[C;D3:1](-[C;D3:...
# 6                  2,3  [C;D2:1](-[C;D3:2](=[C:3](-[c:4])-[c:5])-[n:6]...
# 7                  2,3  [C;D2:1](-[C;D3:2](-[F:3])=[C:4](-[c:5])-[C:6]...
# 8                  2,3  [C;D2:1]-[C;D2:2]-[N;D3:3](-[C;D3:4](=[O:5])-[...
# 9                    2  [C;D2:1]-[N;D2:2]-[C;D2:3]-[C;D3:4]>>[C;D2:1]-...
#
#                                Source_composite_rows  pseudo_reactions_size  \
# 0  n1_t2_composite_rules.tsv:14,n1_t2_composite_r...                     25
# 1  n1_t2_composite_rules.tsv:147,n1_t2_composite_...                     20
# 2  n1_t2_composite_rules.tsv:2474,n1_t2_composite...                     14
# 3  n1_t2_composite_rules.tsv:56,n1_t2_composite_r...                     10
# 4  n1_t2_composite_rules.tsv:5162,n1_t2_composite...                      9
# 5  n1_t2_composite_rules.tsv:239,n1_t2_composite_...                      9
# 6  n1_t2_composite_rules.tsv:2157,n1_t2_composite...                      8
# 7  n1_t2_composite_rules.tsv:168,n1_t2_composite_...                      8
# 8  n1_t2_composite_rules.tsv:2296,n1_t2_composite...                      7
# 9  n1_t2_composite_rules.tsv:238,n1_t2_composite_...                      6
#
#                                  Pseudo_reaction_ids classification  \
# 0  p285,p286,p289,p290,p291,p292,p293,p294,p295,p...       negative
# 1  p372,p373,p374,p375,p376,p377,p378,p379,p380,p...       negative
# 2  p650,p651,p652,p653,p654,p655,p657,p658,p5266,...       negative
# 3  p737,p738,p739,p740,p741,p742,p743,p744,p2922,...       negative
# 4      p783,p784,p785,p786,p787,p788,p789,p790,p7935       negative
# 5  p1690,p1691,p1692,p1693,p2820,p2821,p2822,p282...       negative
# 6   p1030,p1031,p1032,p1033,p1034,p1035,p4951,p11367       negative
# 7  p1403,p1404,p1405,p1406,p1407,p4949,p10926,p11369       negative
# 8         p2893,p2894,p2895,p2896,p5089,p5093,p10997       negative
# 9                p1687,p1688,p1689,p3002,p3003,p5404       negative
#
#    Matched_default_rule_ids                              Matched_default_rules
# 0                       859  [C;D3:1]-[C;D2:2]-[N;D2:3]=[N;D2+:4]>>[C;D3:1]...
# 1                      2219  [C;D2:1]-[C;D2:2]-[N;D2:4]=[N;D2+:5]>>[N;D1-:4...
# 2                       540  [C;D2:1]-[C;D3:2](=[O;D1:6])-[N;D2:8]-[C;D2:7]...
# 3                      1293  [C;D2:1]-[C;D2:2]=[O;D1:3]>>[C;D2:1]-[C;D3:2](...
# 4                      1352  [C;D2:1]-[C;D3:2](=[O;D1:5])-[N;D3:7](-[C;D2:6...
# 5                        51  [C;D3:1]-[C;D2:2]-[O;D1:3]>>[C;D3:1]-[C;D3:2](...
# 6                      1023  [C;D3:1]-[C;D2:2]=[O;D1:3]>>[C;D3:1]-[C;D3:2](...
# 7                       514  [C;D3:1]-[C;D2:2]=[O;D1:3]>>[C;D3:1]-[C;D3:2](...
# 8                       371  [C;D2:1]-[C;D2:2]-[N;D3:5](-[C;D3:4])-[C;D3:6]...
# 9                      1372  [C;D3:1]-[C;D2:2]-[N;D2:4]-[C;D2:3]>>[C;D3:1]-...

# %%
neg_num = 0

smarts(df.iloc[neg_num]['Alchemical_rule'])
